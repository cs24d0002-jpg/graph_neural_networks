# %%
from datasets import load_dataset

ds = load_dataset("KGraph/FB15k-237")
ds.save_to_disk('../data/')
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/20466 [00:00<?, ? examples/s]
